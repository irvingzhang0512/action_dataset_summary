# %%
import pandas as pd
import os
import numpy as np
from collections import defaultdict

# 目标：分析标注结果，寻找标注结果的一些错误
csv_dir = "labels"  # 标注结果所在文件夹（会寻找子目录），后续处理所有`.csv`文件
video_dir = "renames/step1"  # 标注视频所在文件夹（会寻找子目录），后续处理所有`.mp4`文件

# 一些参数
avaiable_cameras = ['2m', '3m', '4m']  # 处理指定摄像头的数据，若为空则处理所有
avaiable_person_ids = [7, 8, 9, 18, 19, 20, 21, 22]
avaiable_persons = ['P%04d' % i for i in avaiable_person_ids]  # 处理指定人物数据，若为空则处理所有

# 可选功能

# 导出标记错误
enable_labeling_err = True
labeling_err_file = './labeling_err.txt'

# 导出统计结果
enable_summary = True
summary_file = './summary.csv'

# 导出质量管理反馈结果
enable_quality_feedback = True
qualify_feedback_file = './quality_feedback.csv'

# %%
csv_list = []
video_list = []

for cur_path, _, file_names in os.walk(csv_dir):
    csv_list += [os.path.join(cur_path, file_name) for file_name in file_names if file_name.endswith(".csv")]
for cur_path, _, file_names in os.walk(video_dir):
    video_list += [file_name for file_name in file_names if file_name.endswith(".mp4")]

# %%
# 拼接所有 csv 结果
df = pd.concat([pd.read_csv(csv_file) for csv_file in csv_list])
df['camera'] = df['image'].str.split('_').map(lambda x:x[1])
df['person'] = df['image'].str.split('_').map(lambda x:x[-1][:5])
if len(avaiable_cameras) > 0:
    df = df[df['camera'].isin(avaiable_cameras)]
if len(avaiable_persons) > 0:
    df = df[df['person'].isin(avaiable_persons)]
df.head()
# Out:
#                                                image        xmin        ymin  \
# 0  close_2m_stand_coldlight_longsleeve_frontshot_...    0.000000   14.844772
# 1  close_2m_stand_coldlight_longsleeve_frontshot_...    0.000000   14.844772
# 2  close_2m_stand_coldlight_longsleeve_frontshot_...    0.000000   14.844772
# 3  close_3m_stand_coldlight_longsleeve_backshot_w...  922.214928  222.381155
# 4  close_3m_stand_coldlight_longsleeve_backshot_w...  922.214928  222.381155
#
#           xmax         ymax               label camera person
# 0   508.315601  1063.755727              medium     2m  P0020
# 1   508.315601  1063.755727  err_action_lacking     2m  P0020
# 2   508.315601  1063.755727               close     2m  P0020
# 3  1174.046288  1015.022070              medium     3m  P0020
# 4  1174.046288  1015.022070  err_action_lacking     3m  P0020

# %%
# 所有labels的集合
frame_type = {'medium', 'end'}
pose_type = {'stand', 'sit', 'squat', 'lie', 'half_lie'}
action_type = {
    'stillfall', 'walkingfall', 'pushoverfall', 'tripfall', 'takephone',
    'takecup', 'eating', 'drinking', 'medicine', 'knock', 'close', 'open'
}
quality_type = {
    'qualified', 'err_camera_lacking', 'err_action_lacking', 'err_light',
    'err_pose', 'err_sleeve', 'err_view', 'err_shelter', 'err_unknown'
}
total_type = frame_type | pose_type | action_type | quality_type

series_error_type = {'err_camera_lacking', 'err_action_lacking', 'err_unknown'}
remade_error_type = {'err_action_lacking'}
useless_error_type = {'err_camera_lacking', 'err_unknown'}
typo_error_type = {'err_light', 'err_pose', 'err_sleeve', 'err_view', 'err_shelter'}

# %%
translations_dict = {
    'qualified': '合格',
    'err_camera_lacking': '画面缺失',
    'err_action_lacking': '动作不完整或动作标注错误',
    'err_light': '光照与文件名不符',
    'err_pose': '姿态与文件名不符',
    'err_sleeve': '衣着与文件名不符',
    'err_view': '视角与文件名不符',
    'err_shelter': '遮挡与文件名不符',
    'err_unknown': '未知错误',

    'medium': '中间帧',
    'end': '结尾帧',
    'stand': '站',
    'sit': '坐',
    'squat': '蹲',
    'lie': '躺',
    'half_lie': '过渡',
    
    'stillfall': '原地软倒',
    'walkingfall': '行进软倒',
    'pushoverfall': '推倒',
    'tripfall': '绊倒',
    'takephone': '拿手机',
    'takecup': '拿水杯',
    'eating': '吃饭',
    'drinking': '喝水',
    'medicine': '吃药',
    'knock': '磕碰',
    'close': '关门',
    'open': '开门',

    'Not_Labeled_or_Wrong_Labeled': '未标注或标注无效',
    'No_Data': '无数据',
}

def _trans_func(context):
    if len(context) > 0:
        segs = set(context.split(" "))
        res = []
        for seg in segs:
            if seg == '':
                continue
            if seg not in translations_dict:
                print('unknown english `{}`'.format(seg))
            else:
                res.append(translations_dict[seg])
        context = ' '.join(res)
    return context

# %%
# 汇总每个bbox的数据
df['bbox'] = df['image'] + df['xmin'].astype(str) + df['ymin'].astype(
    str) + df['xmax'].astype(str) + df['ymax'].astype(str)
df['is_medium'] = df['label'].map(lambda x: 1 if x == 'medium' else 0)
df['is_end'] = df['label'].map(lambda x: 1 if x == 'end' else 0)

def group_by_bbox(x):
    """
    根据 bbox 进行group操作，获取group后每行的结果
    'image', 'action_labels', 'quality_labels', 'pose_labels', 'unknown_labels', 'is_medium'
    文件名，要求行为标签，质量标签，姿态标签，未知标签，是否是中间帧，打标签的错误

    """
    img_name = x.iloc[0, 0]
    cur_filename_action_labels = {img_name.split("_")[0]} & action_type

    # 获取各类标签
    labels = set(list(x['label']))
    cur_action_labels = labels & action_type
    cur_quality_labels = labels & quality_type
    cur_pose_labels = labels & pose_type
    cur_unknown_labels = labels - total_type
    cur_frame_labels = labels & frame_type

    # 当前bbox是否存在问题
    is_unqualified = False
    if len(cur_quality_labels) >= 1 and 'qualified' not in cur_quality_labels:
        is_unqualified = True
    # 当前bbox是否是中间帧

    is_medium = np.array(x['is_medium']).sum()
    is_end = np.array(x['is_end']).sum()
    

    return pd.Series([
        img_name, 
        ' '.join(cur_filename_action_labels),
        ' '.join(cur_action_labels), 
        ' '.join(cur_quality_labels),
        ' '.join(cur_pose_labels), 
        ' '.join(cur_unknown_labels), 
        is_medium,
        is_end,
    ])


group_by_bbox_df = df.groupby("bbox").apply(group_by_bbox)
group_by_bbox_df.columns = [
    'image', 'filename_action_labels', 'action_labels', 'quality_labels', 'pose_labels',
    'unknown_labels', 'is_medium', 'is_end'
]
group_by_bbox_df['index_name'] = group_by_bbox_df['image'].str.split('_').apply(lambda x: x[-1][:5] + '_' + x[1] + '_' + x[0])
group_by_bbox_df.head()
# Out:
#                                                                                                 image  \
# bbox
# close_2m_stand_coldlight_longsleeve_frontshot_w...  close_2m_stand_coldlight_longsleeve_frontshot_...
# close_2m_stand_coldlight_shortsleeve_frontshot_...  close_2m_stand_coldlight_shortsleeve_frontshot...
# close_2m_stand_coldlight_shortsleeve_frontshot_...  close_2m_stand_coldlight_shortsleeve_frontshot...
# close_2m_stand_coldlight_shortsleeve_frontshot_...  close_2m_stand_coldlight_shortsleeve_frontshot...
# close_2m_stand_coldlight_shortsleeve_frontshot_...  close_2m_stand_coldlight_shortsleeve_frontshot...
#
#                                                    filename_action_labels  \
# bbox
# close_2m_stand_coldlight_longsleeve_frontshot_w...                  close
# close_2m_stand_coldlight_shortsleeve_frontshot_...                  close
# close_2m_stand_coldlight_shortsleeve_frontshot_...                  close
# close_2m_stand_coldlight_shortsleeve_frontshot_...                  close
# close_2m_stand_coldlight_shortsleeve_frontshot_...                  close
#
#                                                    action_labels  \
# bbox
# close_2m_stand_coldlight_longsleeve_frontshot_w...         close
# close_2m_stand_coldlight_shortsleeve_frontshot_...
# close_2m_stand_coldlight_shortsleeve_frontshot_...         close
# close_2m_stand_coldlight_shortsleeve_frontshot_...
# close_2m_stand_coldlight_shortsleeve_frontshot_...         close
#
#                                                         quality_labels  \
# bbox
# close_2m_stand_coldlight_longsleeve_frontshot_w...  err_action_lacking
# close_2m_stand_coldlight_shortsleeve_frontshot_...
# close_2m_stand_coldlight_shortsleeve_frontshot_...           qualified
# close_2m_stand_coldlight_shortsleeve_frontshot_...
# close_2m_stand_coldlight_shortsleeve_frontshot_...           qualified
#
#                                                    pose_labels unknown_labels  \
# bbox
# close_2m_stand_coldlight_longsleeve_frontshot_w...
# close_2m_stand_coldlight_shortsleeve_frontshot_...       stand
# close_2m_stand_coldlight_shortsleeve_frontshot_...       stand
# close_2m_stand_coldlight_shortsleeve_frontshot_...       stand
# close_2m_stand_coldlight_shortsleeve_frontshot_...       stand
#
#                                                     is_medium  is_end  \
# bbox
# close_2m_stand_coldlight_longsleeve_frontshot_w...          1       0
# close_2m_stand_coldlight_shortsleeve_frontshot_...          0       0
# close_2m_stand_coldlight_shortsleeve_frontshot_...          1       0
# close_2m_stand_coldlight_shortsleeve_frontshot_...          0       0
# close_2m_stand_coldlight_shortsleeve_frontshot_...          1       0
#
#                                                         index_name
# bbox
# close_2m_stand_coldlight_longsleeve_frontshot_w...  P0020_2m_close
# close_2m_stand_coldlight_shortsleeve_frontshot_...  P0007_2m_close
# close_2m_stand_coldlight_shortsleeve_frontshot_...  P0007_2m_close
# close_2m_stand_coldlight_shortsleeve_frontshot_...  P0008_2m_close
# close_2m_stand_coldlight_shortsleeve_frontshot_...  P0008_2m_close

# %%
# 可能出现的问题

def _get_error_labeling(row):
    # 每个 row 代表一个bbox以及对应的所有标签
    if len(row['action_labels']) > 1:
        action_labels = set(row['action_labels'].split(" "))
    else:
        action_labels = {}
    if len(row['filename_action_labels']) > 1:
        filename_action_labels = set(row['filename_action_labels'].split(" "))
    else:
        filename_action_labels = {}
    if len(row['quality_labels']) > 1:
        quality_labels = set(row['quality_labels'].split(" "))
    else:
        quality_labels = {}
    if len(row['pose_labels']) > 1:
        pose_labels = set(row['pose_labels'].split(" "))
    else:
        pose_labels = {}
    if len(row['unknown_labels']) > 1:
        unknown_labels = set(row['unknown_labels'].split(" "))
    else:
        unknown_labels = {}
    is_medium = row['is_medium']
    is_end = row['is_end']

    result = ''

    # 对于unknown label集中处理
    if len(unknown_labels) > 0:
        result += '存在未知标签 {}。'.format(unknown_labels)
    
    # 帧类别不能同时存在
    if is_medium and is_end:
        result += '同时存在中间帧标签与结尾帧标签。'

    # 对于三类 bbox 分别处理
    
    # 第一类：无中间帧标签+无结尾帧标签
    # 要求 pose label 只有一个
    if not is_medium and not is_end:
        if len(pose_labels) != 1:
            result += '姿态标签不存在或不止一个。'
        return result

    # 第二类：中间帧
    # 1. 如果存在严重的质量问题（需要返工或返工也无法修复），则只需要
    if is_medium:
        if len(quality_labels) == 0:
            result += '漏标质量管理标签。'
        elif len(quality_labels) > 1 or list(quality_labels)[0] != 'qualified':
            if len(quality_labels) > 1 and 'qualified' in quality_labels:
                result += '质量管理标签中同时存在 `qualified` 以及其他错误标签。'

            # 质量存在问题，需要判断质量问题严重性
            if len(quality_labels & series_error_type) > 0:
                # 对于严重错误，不需要考虑其他问题
                return result
        
        # 无质量问题，或存在质量问题但不需要反工时
        # 判断行为标签、姿态标签数量只能有一个
        # 行为标签与文件名中的行为标签保持一致
        if len(action_labels) != 1:
            result += '行为标签遗漏或不止一个。'
        elif list(action_labels)[0] != list(filename_action_labels)[0]:
            result += '行为标签与文件名中的行为标签不同。'
        if len(pose_labels) != 1:
            result += '姿态标签遗漏或不止一个。'
                
        return result

    # 第三类：结尾帧
    # 主要就是考虑行为标签、姿态标签数量必须是1个
    # 判断行为标签与姿态标签
    if len(action_labels) != 1:
        result += '行为标签遗漏或不止一个。'
    elif list(action_labels)[0] != list(filename_action_labels)[0]:
        result += '行为标签与文件名中的行为标签不同。'
    if len(pose_labels) != 1:
        result += '姿态标签遗漏或不止一个。'
    
    return result

group_by_bbox_df['labeling_err_details'] = group_by_bbox_df.apply(lambda row: _get_error_labeling(row), axis=1)
group_by_bbox_df['labeling_err'] = group_by_bbox_df['labeling_err_details'].apply(lambda x: len(x) != 0)
err_labeling_df = group_by_bbox_df[group_by_bbox_df['labeling_err']]
err_labeling_df.head()
# Out:
#                                                                                                 image  \
# bbox
# pushoverfall_2m_stand_coldlight_shortsleeve_fro...  pushoverfall_2m_stand_coldlight_shortsleeve_fr...
# pushoverfall_3m_stand_coldlight_shortsleeve_bac...  pushoverfall_3m_stand_coldlight_shortsleeve_ba...
# pushoverfall_4m_stand_coldlight_shortsleeve_sid...  pushoverfall_4m_stand_coldlight_shortsleeve_si...
#
#                                                    filename_action_labels  \
# bbox
# pushoverfall_2m_stand_coldlight_shortsleeve_fro...           pushoverfall
# pushoverfall_3m_stand_coldlight_shortsleeve_bac...           pushoverfall
# pushoverfall_4m_stand_coldlight_shortsleeve_sid...           pushoverfall
#
#                                                    action_labels  \
# bbox
# pushoverfall_2m_stand_coldlight_shortsleeve_fro...   walkingfall
# pushoverfall_3m_stand_coldlight_shortsleeve_bac...   walkingfall
# pushoverfall_4m_stand_coldlight_shortsleeve_sid...   walkingfall
#
#                                                    quality_labels pose_labels  \
# bbox
# pushoverfall_2m_stand_coldlight_shortsleeve_fro...      qualified    half_lie
# pushoverfall_3m_stand_coldlight_shortsleeve_bac...      qualified    half_lie
# pushoverfall_4m_stand_coldlight_shortsleeve_sid...      qualified    half_lie
#
#                                                    unknown_labels  is_medium  \
# bbox
# pushoverfall_2m_stand_coldlight_shortsleeve_fro...                         1
# pushoverfall_3m_stand_coldlight_shortsleeve_bac...                         1
# pushoverfall_4m_stand_coldlight_shortsleeve_sid...                         1
#
#                                                     is_end  \
# bbox
# pushoverfall_2m_stand_coldlight_shortsleeve_fro...       0
# pushoverfall_3m_stand_coldlight_shortsleeve_bac...       0
# pushoverfall_4m_stand_coldlight_shortsleeve_sid...       0
#
#                                                                index_name  \
# bbox
# pushoverfall_2m_stand_coldlight_shortsleeve_fro...  P0021_2m_pushoverfall
# pushoverfall_3m_stand_coldlight_shortsleeve_bac...  P0021_3m_pushoverfall
# pushoverfall_4m_stand_coldlight_shortsleeve_sid...  P0021_4m_pushoverfall
#
#                                                    labeling_err_details  \
# bbox
# pushoverfall_2m_stand_coldlight_shortsleeve_fro...    行为标签与文件名中的行为标签不同。
# pushoverfall_3m_stand_coldlight_shortsleeve_bac...    行为标签与文件名中的行为标签不同。
# pushoverfall_4m_stand_coldlight_shortsleeve_sid...    行为标签与文件名中的行为标签不同。
#
#                                                     labeling_err
# bbox
# pushoverfall_2m_stand_coldlight_shortsleeve_fro...          True
# pushoverfall_3m_stand_coldlight_shortsleeve_bac...          True
# pushoverfall_4m_stand_coldlight_shortsleeve_sid...          True

# %%
# 导出标记错误信息
if enable_labeling_err:
    labeled_samples = set(list(group_by_bbox_df[group_by_bbox_df['is_medium'] > 0]['index_name'].unique()))
    missing_index_list = []
    for video_name in video_list:
        row = video_name.split("_")
        pid = row[-1][:5]
        if len(avaiable_persons) > 1:
            if pid not in avaiable_persons:
                continue
        cur_index_name = '{}_{}_{}'.format(pid, row[1], row[0])
        if cur_index_name not in labeled_samples:
            missing_index_list.append(cur_index_name)
    
    # 命令行输出结果 & 写入文件
    labeling_err_writer = open(labeling_err_file, "w")

    context = '漏标视频（可能没有标视频，也可能漏了`中间帧`标签）共有 {} 个，分别是：'.format(len(missing_index_list))
    labeling_err_writer.write(context + '\n')
    print(context)

    for sample in missing_index_list:
        print(sample)
        labeling_err_writer.write(sample + '\n')
    print('\n')
    labeling_err_writer.write('\n')

    context = '其他错标视频共有 {} 个，其编号与错误类别如下：'.format(len(err_labeling_df))
    labeling_err_writer.write(context + '\n')
    print(context)
    for row in err_labeling_df.iterrows():
        context = '{}: {}'.format(row[1]['index_name'], row[1]['labeling_err_details'])
        print(context)
        labeling_err_writer.write(context + '\n')
# Out:
# 漏标视频（可能没有标视频，也可能漏了`中间帧`标签）共有 0 个，分别是：
#
#
# 其他错标视频共有 3 个，其编号与错误类别如下：
# P0021_2m_pushoverfall: 行为标签与文件名中的行为标签不同。
# P0021_3m_pushoverfall: 行为标签与文件名中的行为标签不同。
# P0021_4m_pushoverfall: 行为标签与文件名中的行为标签不同。

# %%
# key: {pid}_{camera}
# value: list(actions)
total_samples = defaultdict(list)

for file_name in video_list:
    row = file_name.split("_")
    action = row[0]
    camera = row[1]
    person = row[-1][:5]
    key = "{}_{}".format(person, camera)
    total_samples[key].append(action)

actions = list(action_type)
actions_chinese = [translations_dict[k] for k in actions]


def _generate_action_results(x):
    """
    获取每行(pid+camera)、每列(12个动作)的质量管理结果
    """
    data = [''] * 12
    img_split = list(x['image'])[0].split("_")
    key = img_split[-1][:5] + "_" + img_split[1]
    for row in x.iterrows():
        data[actions.index(row[1][1])] += row[1][3] + ' '
    for idx, ele in enumerate(data):
        if ele == '':
            if actions[idx] in total_samples[key]:
                data[idx] = 'Not_Labeled_or_Wrong_Labeled'
            else:
                data[idx] = 'No_Data'
    return pd.Series(data)

if enable_summary:
    group_by_bbox_df['index_name'] = group_by_bbox_df['image'].str.split('_').apply(lambda x: x[-1][:5] + '_' + x[1])
    group_by_bbox_df = group_by_bbox_df[(group_by_bbox_df['is_medium'] > 0) & (~group_by_bbox_df['labeling_err'])]
    summary_df = group_by_bbox_df.groupby('index_name').apply(_generate_action_results)
    summary_df.columns = actions
    for column in actions:
        summary_df[column] = summary_df[column].str.strip()

    summary_ch_df = summary_df.copy()
    for col in summary_ch_df.columns:
        summary_ch_df[col] = summary_ch_df[col].apply(_trans_func)
    summary_ch_df.columns = [translations_dict[k] for k in list(summary_ch_df.columns)]
    summary_ch_df.to_csv(summary_file)
    summary_ch_df.head()

# %%
summary_df
# Out:
#                          knock            tripfall            medicine  \
# index_name
# P0007_2m             qualified           qualified           qualified
# P0007_3m             qualified           qualified           qualified
# P0007_4m             qualified           qualified           qualified
# P0008_2m             qualified  err_action_lacking           qualified
# P0008_3m             qualified  err_action_lacking           qualified
# P0008_4m             qualified  err_action_lacking           qualified
# P0009_2m    err_camera_lacking  err_action_lacking  err_camera_lacking
# P0009_3m           err_unknown  err_action_lacking            err_pose
# P0009_4m           err_unknown  err_action_lacking           qualified
# P0018_2m             qualified           qualified           qualified
# P0018_3m             qualified           qualified           qualified
# P0018_4m             qualified           qualified           qualified
# P0019_2m    err_action_lacking           qualified           qualified
# P0019_3m    err_action_lacking           qualified           qualified
# P0019_4m    err_action_lacking           qualified           qualified
# P0020_2m             qualified  err_action_lacking  err_action_lacking
# P0020_3m             qualified  err_action_lacking  err_action_lacking
# P0020_4m             qualified  err_action_lacking  err_action_lacking
# P0021_2m             qualified           qualified           qualified
# P0021_3m             qualified           qualified           qualified
# P0021_4m             qualified           qualified           qualified
# P0022_2m    err_camera_lacking           qualified  err_camera_lacking
# P0022_3m    err_action_lacking           qualified  err_action_lacking
# P0022_4m    err_action_lacking           qualified  err_action_lacking
#
#                        drinking               close                open  \
# index_name
# P0007_2m    qualified qualified           qualified           qualified
# P0007_3m    qualified qualified           qualified           qualified
# P0007_4m    qualified qualified           qualified           qualified
# P0008_2m    qualified qualified           qualified           qualified
# P0008_3m    qualified qualified           qualified           qualified
# P0008_4m    qualified qualified           qualified           qualified
# P0009_2m     err_camera_lacking           qualified           qualified
# P0009_3m    qualified qualified           qualified           qualified
# P0009_4m              qualified           qualified           qualified
# P0018_2m              qualified  err_action_lacking           qualified
# P0018_3m              qualified  err_action_lacking           qualified
# P0018_4m              qualified  err_action_lacking           qualified
# P0019_2m              qualified           qualified           qualified
# P0019_3m              qualified           qualified           qualified
# P0019_4m              qualified           qualified           qualified
# P0020_2m              qualified  err_action_lacking           qualified
# P0020_3m              qualified  err_action_lacking           qualified
# P0020_4m              qualified  err_action_lacking           qualified
# P0021_2m                No_Data             No_Data             No_Data
# P0021_3m                No_Data             No_Data             No_Data
# P0021_4m                No_Data             No_Data             No_Data
# P0022_2m              qualified             No_Data             No_Data
# P0022_3m              qualified           qualified  err_action_lacking
# P0022_4m              qualified           qualified  err_action_lacking
#
#                          eating           stillfall  \
# index_name
# P0007_2m    qualified qualified           qualified
# P0007_3m    qualified qualified           qualified
# P0007_4m    qualified qualified           qualified
# P0008_2m    qualified qualified           qualified
# P0008_3m    qualified qualified  err_action_lacking
# P0008_4m    qualified qualified  err_action_lacking
# P0009_2m    qualified qualified           qualified
# P0009_3m    qualified qualified           qualified
# P0009_4m    qualified qualified           qualified
# P0018_2m              qualified  err_action_lacking
# P0018_3m              qualified  err_action_lacking
# P0018_4m              qualified           qualified
# P0019_2m              qualified           qualified
# P0019_3m              qualified           qualified
# P0019_4m              qualified           qualified
# P0020_2m              qualified           qualified
# P0020_3m              qualified           qualified
# P0020_4m              qualified           qualified
# P0021_2m              qualified           qualified
# P0021_3m              qualified           qualified
# P0021_4m              qualified           qualified
# P0022_2m              qualified           qualified
# P0022_3m              qualified           qualified
# P0022_4m              qualified           qualified
#
#                             pushoverfall         walkingfall  \
# index_name
# P0007_2m                       qualified           qualified
# P0007_3m                       qualified           qualified
# P0007_4m                       qualified           qualified
# P0008_2m              err_action_lacking           qualified
# P0008_3m              err_action_lacking           qualified
# P0008_4m              err_action_lacking           qualified
# P0009_2m                       qualified           qualified
# P0009_3m                       qualified           qualified
# P0009_4m                       qualified           qualified
# P0018_2m                       qualified           qualified
# P0018_3m                       qualified           qualified
# P0018_4m                       qualified           qualified
# P0019_2m                       qualified           qualified
# P0019_3m                       qualified           qualified
# P0019_4m                       qualified           qualified
# P0020_2m                       qualified           qualified
# P0020_3m                       qualified           qualified
# P0020_4m                       qualified           qualified
# P0021_2m    Not_Labeled_or_Wrong_Labeled  err_action_lacking
# P0021_3m    Not_Labeled_or_Wrong_Labeled  err_action_lacking
# P0021_4m    Not_Labeled_or_Wrong_Labeled  err_action_lacking
# P0022_2m                       qualified           qualified
# P0022_3m                       qualified           qualified
# P0022_4m                       qualified           qualified
#
#                        takecup           takephone
# index_name
# P0007_2m             qualified           qualified
# P0007_3m             qualified           qualified
# P0007_4m             qualified           qualified
# P0008_2m             qualified           qualified
# P0008_3m             qualified  err_action_lacking
# P0008_4m             qualified  err_action_lacking
# P0009_2m    err_camera_lacking  err_camera_lacking
# P0009_3m             qualified           qualified
# P0009_4m             qualified           qualified
# P0018_2m    err_action_lacking  err_action_lacking
# P0018_3m    err_action_lacking  err_action_lacking
# P0018_4m    err_action_lacking  err_action_lacking
# P0019_2m             qualified           qualified
# P0019_3m             qualified           qualified
# P0019_4m             qualified           qualified
# P0020_2m    err_action_lacking  err_action_lacking
# P0020_3m    err_action_lacking  err_action_lacking
# P0020_4m    err_action_lacking  err_action_lacking
# P0021_2m             qualified  err_action_lacking
# P0021_3m             qualified  err_action_lacking
# P0021_4m             qualified  err_action_lacking
# P0022_2m    err_action_lacking           qualified
# P0022_3m    err_action_lacking           qualified
# P0022_4m    err_action_lacking           qualified

# %%
if enable_summary and enable_quality_feedback:
    qualify_feedback_writer = open(qualify_feedback_file, 'w')
    remade_list = []
    useless_list = []
    typo_list = []

    for row in summary_df.iterrows():
        index_name = row[0]
        for action in row[1].index:
            qualities = set(row[1][action].split(' '))
            context = ' '.join([index_name, translations_dict[action], _trans_func(row[1][action])])
            if len(qualities & useless_error_type) > 0:
                useless_list.append(context)
            if len(qualities & remade_error_type) > 0:
                remade_list.append(context)
            if len(qualities & typo_error_type) > 0:
                typo_list.append(context)
    
    context = "无效数据有 {} 个，分别是：".format(len(useless_list))
    print(context)
    qualify_feedback_writer.write(context + '\n')
    for context in useless_list:
        print(context)
        qualify_feedback_writer.write(context + '\n')
    print()
    qualify_feedback_writer.write('\n')
    
    context = "需要返工数据有 {} 个，分别是：".format(len(remade_list))
    print(context)
    qualify_feedback_writer.write(context + '\n')
    for context in remade_list:
        print(context)
        qualify_feedback_writer.write(context + '\n')
    print()
    qualify_feedback_writer.write('\n')

    context = "有小问题但不影响使用的数据有 {} 个，分别是：".format(len(typo_list))
    print(context)
    qualify_feedback_writer.write(context + '\n')
    for context in typo_list:
        print(context)
        qualify_feedback_writer.write(context + '\n')
    
    qualify_feedback_writer.close()
